# %% [markdown]
# Testing Sample Purpose

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'b54bcf4d-1bca-4e8e-9a24-22ff2c3d462c',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-20T06:05:46.595Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 5669, 'name': 'swq37igf07k', 'symbol': 'rq7s1gvi9w', 'slug': 'snxlrbsenu', 'cmc_rank': 3152, 'num_market_pairs': 6038, 'circulating_supply': 9907, 'total_supply': 6402, 'max_supply': 2964, 'infinite_supply': None, 'last_updated': '2024-02-20T06:05:46.594Z', 'date_added': '2024-02-20T06:05:46.594Z', 'tags': ['2olksqkzmiu', 'f472phgqlrr', 'qimmrf7ed5', 'w71b8iedg3', 'uuay9kch0da', 'uhin1xlmxhr', 'jseqgl4a46i', 'eo0zvjfaqv4', 'ats7e92n99r', 'czoab2qdzne'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.47092192250696097, 'volume_24h': 2431, 'volume_change_24h': 0.3648396860209395, 'percent_change_1h': 0.8730046433273255, 'percent_change_24h': 0.12370474528919773, 'percent_change_7d': 0.24609768383021313, 'market_cap': 0.914243792475965, 'market_cap_dominan
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm=pd.json_normalize(data['data'])
norm
# Out:
#      id         name       symbol         slug  cmc_rank  num_market_pairs  \
# 0  1109  prumj3sz6ns  uyrb60w4w3r  lxud4oe5uaq      5369              5149
# 1  6681  ldh6h7ltunl  1gnxnz515mj  an4d7sb595p      1617              4423
# 2  2421  bb9306kqmbh   m69r8qz6mx  52ff1k2zhso      8102              1957
# 3  2095  bybwfhsj8v9   h6ekcz4jww  7frk0sktw99      4716              1881
# 4  2577  k45g4swt8ba  3acgrd21tfy   bbr8zixela      4243              8006
# 5  5028  law2prna5fb   hkahpzuk5p   tjtinskn2z       963              3293
# 6  7916    iy2rb5fff  j1sezvphbhh   3qzsqvjm2u      9614              1156
# 7  2907  75jawsqoren  va8w7438kvq  vb2iibrdvqo      8870              7240
# 8  1633  rgh76dilxos   ps6i0rh97v  pdfh4x94toa      1453              2298
# 9  9322  7bktinb2336  m83r6stdb9j  3m6e0vr9odb       873              2526
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# 0                8140          5688        7638            None  ...
# ...

# %% [markdown]
# Testing Actual API

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'100',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '6194b402-89c1-401f-b823-e13e4392ebb0',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-20T06:06:32.217Z', 'error_code': 0, 'error_message': None, 'elapsed': 105, 'credit_count': 1, 'notice': None, 'total_count': 8818}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10821, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'p
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm=pd.json_normalize(data['data'])
norm
# Out:
#        id           name symbol           slug  num_market_pairs  \
# 0       1        Bitcoin    BTC        bitcoin             10821
# 1    1027       Ethereum    ETH       ethereum              8428
# 2     825    Tether USDt   USDT         tether             74897
# 3    1839            BNB    BNB            bnb              2070
# 4    5426         Solana    SOL         solana               626
# ..    ...            ...    ...            ...               ...
# 95   7548          WEMIX  WEMIX          wemix                52
# 96   1659         Gnosis    GNO     gnosis-gno               169
# 97   1042        Siacoin     SC        siacoin                95
# 98  13631  Manta Network  MANTA  manta-network                84
# 99  17799         Axelar    AXL         axelar                82
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# ...

# %% [markdown]
# Random Fox API

# %%
import requests

# %%
page = requests.get('https://randomfox.ca/floof/')

# %%
print(page.status_code)
# Out:
# 200

# %%
print(page.text)
# Out:
# {"image":"https:\/\/randomfox.ca\/images\/52.jpg","link":"https:\/\/randomfox.ca\/?i=52"}

# %%
fox=page.json()
image=fox['image']
print(image)
# Out:
# https://randomfox.ca/images/52.jpg

# %%
#using actual api

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://api.nettoolkit.com/v1/account/test-api-keys'  #actual url
parameters = {
  'start':'1',
  'limit':'100',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'test_wPMqcwtZ93zeKp2RgQ5OGg9dWAOuT6eNKFAEbikR',  #actual api key
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
   print(e)
# Out:
# {'code': 1000, 'message': '', 'results': [{'created': 1708413144005, 'ip': '34.31.56.102', 'id': '01f7826a-5aaf-4072-a9de-7ada36a8b48a', 'type': 'test_api_key', 'key': 'test_fPT09qRvWdSrV1WtIWNK0rEuDKMSG8xzt4j92SVb'}]}

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm=pd.json_normalize(data['results'])
norm
# Out:
#          created            ip                                    id  \
# 0  1708413144005  34.31.56.102  01f7826a-5aaf-4072-a9de-7ada36a8b48a
#
#            type                                            key
# 0  test_api_key  test_fPT09qRvWdSrV1WtIWNK0rEuDKMSG8xzt4j92SVb
