# %%
#time analysis of pandas using gold price
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('/content/Gold Price.csv')

date_rng = pd.date_range(start='2015-01-01', end='2022-12-31', freq='D')
df = pd.DataFrame(date_rng, columns=['date'])
np.random.seed(42)
df['data'] = np.random.randint(0, 100, size=(len(date_rng)))
np.random.seed(42)
df['data'] = np.random.randint(0, 100, size=(len(date_rng)))
df.set_index('date', inplace=True)
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['data'], label='Time Series Data')
plt.title('Time Series Plot')
plt.xlabel('Date')
plt.ylabel('Data Value')
plt.legend()
plt.show()
df_resampled = df.resample('M').mean()
df['2024-01-03':'2024-01-07']
# Out:
# Empty DataFrame
# Columns: [data]
# Index: []

# %%
import pandas as pd

# Step 2: Read CSV
df = pd.read_csv('/content/Gold Price.csv')

# Step 3: Parse Dates
df['Date'] = pd.to_datetime(df['Date'])  # Assuming 'Date' is the column name with time-related data

# Step 4: Set Index
df.set_index('Date', inplace=True)

# Step 5: Data Manipulation/Analysis
# Example: Calculate mean of a column
mean_value = df['Price'].mean()  # Assuming the correct column name is 'Price'

# Step 6: Visualization (Optional)
import matplotlib.pyplot as plt

# Example: Plotting
plt.plot(df.index, df['Price'])
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Time Series Data')
plt.show()
